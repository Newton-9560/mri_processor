# %%
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import imageio

import numpy as np

def normalize_image(image):
    # 计算0.5%和99.5%分位数
    lower_percentile = np.percentile(image, 0.5)
    upper_percentile = np.percentile(image, 99.5)

    # 裁剪图像
    clipped_image = np.clip(image, lower_percentile, upper_percentile)

    # 计算均值和标准差
    mean = np.mean(clipped_image)
    std = np.std(clipped_image)

    # 标准化图像
    normalized_image = (clipped_image - mean) / std

    return normalized_image

# %%
img = plt.imread('./t1w2t2w/t1w/sub-CC00054XX05_ses-8800_100d1.png')
img = Image.open('./t1w2t2w/t2w/sub-CC00054XX05_ses-8800_100d1.png')

# %%
img[120][120]*255
# Out:
# 11.000000294297934

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(img)
img_minmax = scaler.transform(img)

# %%
plt.imshow(img_minmax,'gray')
plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/newton/桌面/datasets/process.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/home/newton/%E6%A1%8C%E9%9D%A2/datasets/process.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> plt.imshow(img_minmax,'gray')
#       <a href='vscode-notebook-cell:/home/newton/%E6%A1%8C%E9%9D%A2/datasets/process.ipynb#W4sZmlsZQ%3D%3D?line=1'>2</a> plt.axis('off')
#
# NameError: name 'img_minmax' is not defined

# %%
plt.imshow(img,'gray')
# plt.axis('off')

# %%
plt.imsave('1.png', img,cmap = 'gray')

# %%
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /home/newton/桌面/datasets/process.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/home/newton/%E6%A1%8C%E9%9D%A2/datasets/process.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> cv2.imshow('img', img)
#       <a href='vscode-notebook-cell:/home/newton/%E6%A1%8C%E9%9D%A2/datasets/process.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> cv2.waitKey(0)
#       <a href='vscode-notebook-cell:/home/newton/%E6%A1%8C%E9%9D%A2/datasets/process.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> cv2.destroyAllWindows()
#
# error: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'imshow'
# > Overload resolution failed:
# >  - mat is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::cuda::GpuMat> for argument 'mat'
# >  - Expected Ptr<cv::UMat> for argument 'mat'
